# %%
import pandas as pd
import numpy as np
import matplotlib.cm as cm

# %%
merged2021 = pd.read_csv('merged_2021.csv', index_col='stu_uuid')
ext_details_df = pd.read_csv('ext_details_df.csv')

# %% [markdown]
# **Plot NAPLAN 2021 percentile scores against Internal Assessment percentiles**
#
# Observations:
#
# Some outliers, Clusters of students performing poor in either test, Linear trend in general

# %%
merged2021.plot.scatter('2021', 'naplan_2021')
# Out:
# <AxesSubplot:xlabel='2021', ylabel='naplan_2021'>

# %% [markdown]
# **K-Means**

# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(
   init="random",
   n_clusters=6,
   n_init=10,
   max_iter=300,
   random_state=42
)

# %%
kmeans.fit(merged2021)
# Out:
# KMeans(init='random', n_clusters=6, random_state=42)

# %%
kmeans.cluster_centers_
# Out:
# array([[51.44302219, 41.77065767],
#        [88.74964452, 92.1951756 ],
#        [56.0491632 , 80.1305081 ],
#        [80.01516567, 65.62274151],
#        [18.52524795, 24.44403457],
#        [23.38993199, 55.89570632]])

# %%
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
}

# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(merged2021)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(
    range(1, 11), sse, curve="convex", direction="decreasing"
)

kl.elbow
# Out:
# 3

# %%
kmeans = KMeans(
   init="random",
   n_clusters=3,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

# %%
kmeans = KMeans(
   init="random",
   n_clusters=4,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

# %%
kmeans = KMeans(
   init="random",
   n_clusters=5,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

# %%
kmeans = KMeans(
   init="random",
   n_clusters=7,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

# %%
kmeans = KMeans(
   init="random",
   n_clusters=8,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

# %%
kmeans = KMeans(
   init="random",
   n_clusters=9,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)

print(kmeans.labels_)
print(kmeans.cluster_centers_)
# Out:
# [0 3 2 0 4 5 8 2 2 8 6 4 8 7 0 5 2 4 4 2 4 7 4 6 5 2 8 0 3 4 5 7 4 7 1 0 1
#  4 8 7 2 4 7 5 1 2 4 8 4 2 1 6 5 3 7 5 1 7 7 7 3 6 0 3 3 0 1 4 8 7 6 5 7 7
#  2 2 0 1 8 7 1 7 0 3 5 5 5 0 1 4 1 2 6 8 2 8 4 2 2 4 5 6 8 4 0 7 2 0 4 0 2
#  1 4 6 7 2 3 4 2 4 0 0 7 4 4 0 1 4 2 8 0 0 4 0 6 7 0 3 7 3 0 6 5 6 0 7 0 8
#  8 0 3 0 0 7 8 0 4 4 7 5 6 5 0 2 4 1 5 6 1 3 3 4 3 8 0 0 2 1 6 6 4 5 6 0 8
#  2 4 1 2 0 3 4 4 6 3 2 0 7 8 1 7 0 7 6 8 4 6 0 3 1 7 0 1 7 6 3 3 1 3 6 5 6
#  2 4 7 6 7 3 1 6 8 2 2 3 7 0 6 2 3 1 0 1 3 5 6 7 1 3 0 8 8 2 5 0 7 6 7 3 6
#  2 3 2 3 2 5 1 5 4 6 8 2 0 5 0 7 4 2 0 6 4 4 3 6 7 7 8 3]
# [[89.89318162 92.38793678]
#  [22.84406137 60.82293423]
#  [82.54812991 67.16453867]
#  [ 9.90620861 31.51208544]
#  [58.19751066 84.4510745 ]
#  [55.10595152 34.61397463]
#  [30.76351382 36.75678616]
#  [54.97937328 58.63907753]
#  [22.64298959 13.65935919]]

# %%
kmeans = KMeans(
   init="random",
   n_clusters=10,
   n_init=10,
   max_iter=300,
   random_state=42
)

kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)
print(kmeans.cluster_centers_)
# Out:
# [[33.99659289 38.64826484]
#  [57.56257174 32.34026607]
#  [59.58357432 60.26722013]
#  [49.1084724  85.28667791]
#  [85.20919022 67.23078776]
#  [22.64298959 13.65935919]
#  [10.20665353 31.77936137]
#  [24.13644771 60.90812566]
#  [70.95303926 85.73096381]
#  [92.09089798 92.7815252 ]]

# %%
cm.rainbow(np.linspace(0, 1, 11))
# Out:
# array([[5.00000000e-01, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [3.03921569e-01, 3.03152674e-01, 9.88165472e-01, 1.00000000e+00],
#        [1.00000000e-01, 5.87785252e-01, 9.51056516e-01, 1.00000000e+00],
#        [9.60784314e-02, 8.05380919e-01, 8.92400583e-01, 1.00000000e+00],
#        [3.00000000e-01, 9.51056516e-01, 8.09016994e-01, 1.00000000e+00],
#        [5.03921569e-01, 9.99981027e-01, 7.04925547e-01, 1.00000000e+00],
#        [7.00000000e-01, 9.51056516e-01, 5.87785252e-01, 1.00000000e+00],
#        [9.03921569e-01, 8.05380919e-01, 4.51244057e-01, 1.00000000e+00],
#        [1.00000000e+00, 5.87785252e-01, 3.09016994e-01, 1.00000000e+00],
#        [1.00000000e+00, 3.03152674e-01, 1.53391655e-01, 1.00000000e+00],
#        [1.00000000e+00, 1.22464680e-16, 6.12323400e-17, 1.00000000e+00]])

# %%
kmeans = KMeans(
   init="random",
   n_clusters=11,
   n_init=10,
   max_iter=300,
   random_state=42
)

colors = cm.rainbow(np.linspace(0, 1, 11))
kmeans.fit(merged2021)
plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=kmeans.labels_)
print(kmeans.cluster_centers_)
# Out:
# [[27.22634839 37.02220349]
#  [64.34337877 27.16882144]
#  [60.85976354 60.81636183]
#  [49.1084724  85.28667791]
#  [85.61328796 67.49109987]
#  [22.64298959 13.65935919]
#  [ 9.63755056 31.31360121]
#  [24.13644771 60.90812566]
#  [71.15669662 86.22596965]
#  [92.09089798 92.7815252 ]
#  [45.28815263 40.99681469]]

# %%
cluster_index_df = pd.DataFrame({'cluster': kmeans.labels_, 'stu_uuid': merged2021.index})
cluster_index_df.set_index('stu_uuid', inplace=True)

# %% [markdown]
# **DBSCAN**

# %%
from sklearn.cluster import DBSCAN


dbscan = DBSCAN(eps=7, min_samples=2).fit(merged2021)

plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=dbscan.labels_)
print(set(dbscan.labels_))
# Out:
# {0, 1, 2, 3, -1}

# %%
from sklearn.cluster import OPTICS


optics = OPTICS(min_samples=2).fit(merged2021)

plt.scatter(merged2021['2021'], merged2021['naplan_2021'], c=optics.labels_)

# %%
ext_details_df[ext_details_df['test_year']==2021]['stu_uuid'].nunique()
# Out:
# 285

# %% [markdown]
# **NAPLAN Question Details of 1 student missing**

# %%
print(ext_details_df['stu_uuid'].nunique())
print(cluster_index_df.index.nunique())
print(ext_details_df[ext_details_df['stu_uuid'].isin(cluster_index_df.index)]['stu_uuid'].nunique())
# Out:
# 288
# 287
# 286

# %%
stu_gp = ext_details_df[ext_details_df['test_year']==2021].groupby(['stu_uuid'])
(stu_gp['lerq_uuid'].count()==48).sum()
# ['attempted'].value_counts()
# Out:
# 285

# %%
# ext_details_df = ext_details_df[cluster_index_df.index.intersection(ext_details_df['stu_uuid'])]
common = cluster_index_df.index.intersection(ext_details_df['stu_uuid'])
ext_details_df = ext_details_df[ext_details_df['stu_uuid'].isin(common)]

# %%
ext_details_df['stu_uuid'].nunique()
# Out:
# 286

# %%
cluster_index_df = cluster_index_df.loc[cluster_index_df.index.isin(common), :]
cluster_index_df.loc[ext_details_df['stu_uuid'], :]
# Out:
#                                       cluster
# stu_uuid
# 3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a        2
# 3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a        2
# 3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a        2
# 3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a        2
# 3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a        2
# ...                                       ...
# 3ff4241d-5b45-17e3-794c-adbbe616c000        9
# 3ff4241d-5b45-17e3-794c-adbbe616c000        9
# 3ff4241d-5b45-17e3-794c-adbbe616c000        9
# 3ff4241d-5b45-17e3-794c-adbbe616c000        9
# 3ff4241d-5b45-17e3-794c-adbbe616c000        9
#
# [35569 rows x 1 columns]

# %%
cluster_mem = cluster_index_df.loc[ext_details_df['stu_uuid'], 'cluster']
ext_details_df['cluster'] = cluster_mem.values
ext_details_df
# Out:
#                                    stu_uuid  test_year  \
# 0      3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a       2017
# 1      3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a       2017
# 2      3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a       2017
# 3      3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a       2017
# 4      3ff48b2a-3132-5a05-74f9-8a6ab2f5e24a       2017
# ...                                     ...        ...
# 35737  3ff4241d-5b45-17e3-794c-adbbe616c000       2017
# 35738  3ff4241d-5b45-17e3-794c-adbbe616c000       2017
# 35739  3ff4241d-5b45-17e3-794c-adbbe616c000       2017
# 35740  3ff4241d-5b45-17e3-794c-adbbe616c000       2017
# 35741  3ff4241d-5b45-17e3-794c-adbbe616c000       2017
#
#                                   lerq_uuid               ext_id  question  \
# 0      a3b1daed-e209-49b1-01cd-cd3c78736404  2017-05|NUMERACY-08       NaN
# 1      a3b155e8-9e96-b10d-8e2f-902e55545d70  2017-05|NUMERACY-01       NaN
# 2      a3b13c69-575f-d7c1-a9f3-50b76234fc97  2017-05|NUMERACY-02       NaN
# ...

# %%
cluster_gp = ext_details_df.groupby(['cluster'])

# %%
cluster_gp['attempted'].sum()/cluster_gp['attempted'].count()
# Out:
# cluster
# 0    0.973040
# 1    0.976519
# 2    0.986011
# 3    0.993569
# 4    0.990325
# 5    0.959677
# 6    0.983686
# 7    0.980911
# 8    0.994431
# 9    0.998198
# Name: attempted, dtype: float64

# %%
topics = ext_details_df['label'].unique().tolist()
topics
# Out:
# ['NUMBER AND ALGEBRA',
#  'STATISTICS AND PROBABILITY',
#  'MEASUREMENT AND GEOMETRY',
#  'NUMBER',
#  'SPACE',
#  'MEASUREMENT, CHANCE & DATA',
#  'STRUCTURE']

# %%
# Out:
# array([[33.99659289, 38.64826484],
#        [57.56257174, 32.34026607],
#        [59.58357432, 60.26722013],
#        [49.1084724 , 85.28667791],
#        [85.20919022, 67.23078776],
#        [22.64298959, 13.65935919],
#        [10.20665353, 31.77936137],
#        [24.13644771, 60.90812566],
#        [70.95303926, 85.73096381],
#        [92.09089798, 92.7815252 ]])

# %%
centers = kmeans.cluster_centers_

for cluster_idx in range(10):
    print(f"Cluster {cluster_idx}: INTERNAL = {centers[cluster_idx][0]}, NAPLAN = {centers[cluster_idx][1]}")
    for topic in topics:
        clus = ext_details_df[ext_details_df['cluster']==cluster_idx]
        cluster_topic = clus[clus['label']==topic]
        print(f"{topic}: {cluster_topic['is_correct'].sum()/cluster_topic.shape[0]}")
    print("\n")
# Out:
# Cluster 0: INTERNAL = 33.99659289430251, NAPLAN = 38.64826484423537
# NUMBER AND ALGEBRA: 0.618698441796517
# STATISTICS AND PROBABILITY: 0.6954397394136808
# MEASUREMENT AND GEOMETRY: 0.5716666666666667
# NUMBER: 0.6390532544378699
# SPACE: 0.6538461538461539
# MEASUREMENT, CHANCE & DATA: 0.5244755244755245
# STRUCTURE: 0.6923076923076923
#
#
# Cluster 1: INTERNAL = 57.562571741005634, NAPLAN = 32.34026606707888
# NUMBER AND ALGEBRA: 0.5754189944134078
# STATISTICS AND PROBABILITY: 0.69
# MEASUREMENT AND GEOMETRY: 0.54421768707483
# NUMBER: 0.6153846153846154
# SPACE: 0.5833333333333334
# MEASUREMENT, CHANCE & DATA: 0.42424242424242425
# STRUCTURE: 0.7222222222222222
#
#
# Cluster 2: INTERNAL = 59.583574320416425, NAPLAN = 60.26722013231288
# NUMBER AND ALGEBRA: 0.744206008583691
# STATISTICS AND PROBABILITY: 0.7935779816513762
# MEASUREMENT AND GEOMETRY: 0.6880877742946708
# NUMBER: 0.5811965811965812
# SPACE: 0.6805555555555556
# MEASUREMENT, CHANCE & DATA: 0.5858585858585859
# ...
